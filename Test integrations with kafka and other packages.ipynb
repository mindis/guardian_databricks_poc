# %%
try:
  import tensorflow as tf
  print ("TensorFlow is already installed")
except ImportError:
  print("Installing TensorFlow")
  import subprocess
  subprocess.check_call(["/databricks/python/bin/pip", "install", ""])
  print("TensorFlow has been installed on this cluster")
  
  
  
  dbutils.library.installPyPI("tensorflow")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Installing TensorFlow
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ModuleNotFoundError</span>                       Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-880112077097276&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg">   </span><span class="ansi-green-fg">import</span> tensorflow <span class="ansi-green-fg">as</span> tf
# <span class="ansi-green-intense-fg ansi-bold">      3</span>   print <span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;TensorFlow is already installed&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">ModuleNotFoundError</span>: No module named &#39;tensorflow&#39;
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">CalledProcessError</span>                        Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-880112077097276&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>   print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;Installing TensorFlow&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span>   <span class="ansi-green-fg">import</span> subprocess
# <span class="ansi-green-fg">----&gt; 7</span><span class="ansi-red-fg">   </span>subprocess<span class="ansi-blue-fg">.</span>check_call<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#34;/databricks/python/bin/pip&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;install&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;&#34;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      8</span>   print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;TensorFlow has been installed on this cluster&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      9</span>
#
# <span class="ansi-green-fg">/usr/lib/python3.7/subprocess.py</span> in <span class="ansi-cyan-fg">check_call</span><span class="ansi-blue-fg">(*popenargs, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    361</span>         <span class="ansi-green-fg">if</span> cmd <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    362</span>             cmd <span class="ansi-blue-fg">=</span> popenargs<span class="ansi-blue-fg">[</span><span class="ansi-cyan-fg">0</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-fg">--&gt; 363</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">raise</span> CalledProcessError<span class="ansi-blue-fg">(</span>retcode<span class="ansi-blue-fg">,</span> cmd<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    364</span>     <span class="ansi-green-fg">return</span> <span class="ansi-cyan-fg">0</span>
# <span class="ansi-green-intense-fg ansi-bold">    365</span>
#
# <span class="ansi-red-fg">CalledProcessError</span>: Command &#39;[&#39;/databricks/python/bin/pip&#39;, &#39;install&#39;, &#39;&#39;]&#39; returned non-zero exit status 1.</div>

# %%
dbutils.library.installPyPI("tensorflow")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: True</div>

# %%
dbutils.library.installPyPI("torch")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: True</div>

# %%
dbutils.library.installPyPI("xgboost")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: True</div>

# %%
import tensorflow as tf
import torch
import torch.nn as nnkafkacat -C -b 2.tcp.ngrok.io:18635 -t event-splitter.audit_logs
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
import xgboost as xgb
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
a=tf.keras.Sequential()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
kafka = (spark.readStream
  .format("kafka")
  .option("kafka.bootstrap.servers", "2.tcp.ngrok.io:16850")
  .option("subscribe", "event-splitter.audit_logs")
  .load())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(kafka)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiYTcxNDgzZGI4MTc0NGQwYWEwMTczN2Y2MTNhMzc1NjUiLCJsb2dnZXJfZXZlbnRfaWQiOiJmZjEwNjRjZi1jMmJjLTRkOGYtYWUxZC0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346970</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiYjVmZDFiZmRlNGQzNGJiMWIwZjdlOWNmZGM1ZDY5MjIiLCJsb2dnZXJfZXZlbnRfaWQiOiIwMWU5ZDZlYy1mMjUyLTQ1YjctOTVlYy0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346971</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiMDhmMzdiZGFmOTE4NDBhNzlhOTljOGQ3YjI1ODZiNDYiLCJsb2dnZXJfZXZlbnRfaWQiOiIxN2Q1ZGU3Mi0wMmU0LTRmMzgtYmRmMC0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346972</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiM2MwMTRiNmFlOTg4NDQ3Nzk4NWYyYjM1YzYyZWMzN2YiLCJsb2dnZXJfZXZlbnRfaWQiOiI5MTJkYjk4Zi05MTg4LTQyODAtYTYwMi0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346973</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiZjQzYjBhZTNhN2IxNDY1NmEzNmY4NDcxYTQyODNhYzAiLCJsb2dnZXJfZXZlbnRfaWQiOiJmNWY4YjNmNC05MDIzLTQ5Y2YtYjg3NS0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346974</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiMjQzNzc3M2NmZjk2NGI1ZTk4ZTRhNzVmY2RmNjI1NTgiLCJsb2dnZXJfZXZlbnRfaWQiOiI2NTIwMzUxOC04ZWNiLTQ0NmQtYjhhMi0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346975</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiYjJmOTQyMGU4NGU3NDI5Y2E1Y2I1YmIwNDZhYjRhMGYiLCJsb2dnZXJfZXZlbnRfaWQiOiJiODhkMTM1ZC0zMThhLTRmM2QtODViNS0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346976</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiODRlNDlhYzZmYzgxNDI2OGE2Y2E4ZWQ5YzFlM2NjZjkiLCJsb2dnZXJfZXZlbnRfaWQiOiIwNzE2NzM4NS1jYTAxLTRjZmYtOWI2YS0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346977</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiZDY1MTg5NDcwYWFjNGYxNjhiNGNlMGNhNzQ4YmM4NjEiLCJsb2dnZXJfZXZlbnRfaWQiOiJkNmM2YWQ2MC1hYzQ4LTQ5NzgtOWM1NS0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346978</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiM2Q4MGI2Nzc3ZTU2NGY1NGJmODUyMDM0M2U5YTViM2EiLCJsb2dnZXJfZXZlbnRfaWQiOiJlNGFkYzc0MC1hYjU0LTRhMjMtYjU0Ni0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346979</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiZjgzM2E0MTE4NTUyNGU5ZWI1ZTc3ZDQ2YTk4NGVhMTUiLCJsb2dnZXJfZXZlbnRfaWQiOiI0MzEzOGFkZC02M2RjLTQ4ZjgtYmQzOC0= (truncated)</td><td>event-splitter.audit_logs</td><td>0</td><td>346980</td><td>2020-10-02T11:13:01.264+0000</td><td>0</td></tr><tr><td>null</td><td>eyJldmVudF90eXBlIjoiY3JlYXRlX2F1ZGl0X29wZXJhdGlvbiIsImV2ZW50X2lkIjoiNDA2ZGI1Mjk4ZDk3NDBlYmE3YjQ4ZWMzMTY4OTQwYWYiLCJsb2dnZXJfZXZlbnRfaWQiOiJkZjA5NzIyOC0wMTJhLTRlN2ItYjg3MS0= (truncated)</td><td>event-s ...

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame[key: binary, value: binary, topic: string, partition: int, offset: bigint, timestamp: timestamp, timestampType: int]
# </div>

# %%
# %%bash
# git clone https://github.com/domoritz/gameoflife-python.git
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Cloning into &#39;gameoflife-python&#39;...
# </div>

# %%
# %sql
select * from anomalies_data_delta_PN_job
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>Ips</th><th>prediction</th></tr></thead><tbody><tr><td>5f208b97dbb387119cf29e72</td><td>1</td><td>1.0</td></tr><tr><td>5eab33cb72855656fa557308</td><td>1</td><td>1.0</td></tr><tr><td>5ea1f15d6eece000099ccf1d</td><td>1</td><td>1.0</td></tr><tr><td>5e14e193a5b4a2000997a2de</td><td>1</td><td>1.0</td></tr><tr><td>5efe479df1af357e14edf9e4</td><td>1</td><td>1.0</td></tr><tr><td>5ed141c113f5e728e6f39768</td><td>1</td><td>1.0</td></tr><tr><td>5ef11d0de5a1110d0e5d70a3</td><td>1</td><td>1.0</td></tr><tr><td>5eb1c979597566000966b55d</td><td>1</td><td>1.0</td></tr><tr><td>5d360a075e3222001cea7808</td><td>2</td><td>1.0</td></tr><tr><td>5ef4ac4babe0a775328b33ef</td><td>1</td><td>1.0</td></tr><tr><td>5942adce54b3ca000ece36c8</td><td>1</td><td>1.0</td></tr><tr><td>5eab60301cb3980251e9ac8b</td><td>1</td><td>1.0</td></tr><tr><td>5e8bb826211337000942380c</td><td>1</td><td>1.0</td></tr><tr><td>5eab27895644cd3abda71142</td><td>1</td><td>1.0</td></tr><tr><td>5e20d12cd7990d000c544872</td><td>1</td><td>1.0</td></tr><tr><td>5efc9eac059a896c2ed18d18</td><td>1</td><td>1.0</td></tr><tr><td>5d4b4142a5664a4349d2ed4c</td><td>1</td><td>1.0</td></tr><tr><td>5d420d03175ff50015a45cae</td><td>2</td><td>1.0</td></tr><tr><td>5ed128f8cae8a70007797c95</td><td>1</td><td>1.0</td></tr><tr><td>5c1ffc