# %%
#dbutils.library.installPyPI("mlflow")
#dbutils.library.restartPython()
from pyspark.sql.types import StructType
from pyspark.sql.types import *
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType
from pyspark.sql.functions import *      # for window() function
from typing import List
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
### method 1 to create tables:
### - create schema
### - create empty spark dataframe whith schema
### - create tables from spark dataframe

#creating schemas
schema_raw_logs = (  StructType()
  .add("account_id","string")
  .add("agent_id","string")
  .add("event",StructType()
         .add("actor",StructType()
             .add("user_id","string")
             .add("ip_addresses",ArrayType(StructType([])))
             .add("session_id","string")
             .add("impersonated_user_id","string")
             .add("id","string")
             .add("type","string")
             .add("user_agent","string")
         )
         .add("account_id","string")
         .add("event_type","string")
         .add("audit",StructType()
              .add("severity","string")
              .add("resource_id","string")
              .add("operation","string")
              .add("timestamp","timestamp")
              .add("status","string")
         )
         .add("logger_event_id","string")     
         .add("object",StructType())
         .add("timestamp","timestamp") 
   )
   .add("timestamp","timestamp") 
)


schema_raw_anomalies = (  StructType()
  .add("anomaly_timestamp","timestamp")
  .add("bucket_start_timestamp","timestamp")
  .add("bucket_finish_timestamp","timestamp")  
  .add("bucket_interval","string")
  .add("account_id","string")
  .add("user_id","string")
  .add("anomaly","integer")
  .add("probability","double")
  .add("top_contributers_1","string")
  .add("top_contributers_2","string")       
  .add("top_contributers_3","string")
)

#create spark dataframes with schemas
#df_logs = spark.createDataFrame(spark.sparkContext.emptyRDD(),schema_raw_logs)
#df_anomalies = spark.createDataFrame(spark.sparkContext.emptyRDD(),schema_raw_anomalies)

#create tables using pre-existent dataframes
# not working yet
#df_logs.write.format("delta").save("/delta/raw_log_data_delta")
#df_anomalies.write.format("delta").save("/delta/anomalies_data_delta")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#method 2 is creating the tables recurring to SQL (bellow)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
CREATE TABLE br_raw_log_data_delta_ (
  account_id STRING,
  agent_id STRING,
  user_id STRING,
  ip_addresses STRING,
  session_id STRING,
  impersonated_user_id STRING,
  id STRING,
  type STRING,
  user_agent STRING,
  event_type STRING,
  severity STRING,
  resource_id STRING,
  operation STRING,
  status STRING,
  logger_event_id STRING,
  object STRING,
  timestamp DATE
 )
USING DELTA;


CREATE TABLE br_anomalies_data_delta_ (
  anomaly_timestamp DATE,
  bucket_start_timestamp DATE,
  bucket_finish_timestamp DATE,
  bucket_interval STRING,
  account_id STRING,
  user_id STRING,
  anomaly INTEGER,
  probability DOUBLE,
  top_contributers_1 STRING,
  top_contributers_2 STRING,
  top_contributers_3 STRING
)
USING DELTA;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.DatabricksExceptions$SQLExecutionException: org.apache.spark.sql.catalyst.analysis.TableAlreadyExistsException: Table default.br_raw_log_data_delta_ already exists;
# 	at org.apache.spark.sql.execution.datasources.v2.CreateTableExec.run(CreateTableExec.scala:47)
# 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.result$lzycompute(V2CommandExec.scala:39)
# 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.result(V2CommandExec.scala:39)
# 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.executeCollect(V2CommandExec.scala:45)
# 	at org.apache.spark.sql.Dataset.$anonfun$logicalPlan$1(Dataset.scala:233)
# 	at org.apache.spark.sql.Dataset.$anonfun$withAction$1(Dataset.scala:3684)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withCustomExecutionEnv$5(SQLExecution.scala:116)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:248)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withCustomExecutionEnv$1(SQLExecution.scala:101)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:835)
# 	at org.apache.spark.sql.execution.SQLExecution$.withCustomExecutionEnv(SQLExecution.scala:77)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:198)
# 	at org.apache.spark.sql.Dataset.withAction(Dataset.scala:3682)
# 	at org.apache.spark.sql.Dataset.<init>(Dataset.scala:233)
# 	at org.apache.spark.sql.Dataset$.$anonfun$ofRows$2(Dataset.scala:103)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:835)
# 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:100)
# 	at org.apache.spark.sql.SparkSession.$anonfun$sql$1(SparkSession.scala:670)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:835)
# 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:665)
# 	at org.apache.spark.sql.SQLContext.sql(SQLContext.scala:672)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.$anonfun$executeSql$1(SQLDriverLocal.scala:90)
# 	at scala.collection.TraversableLike.$anonfun$map$1(TraversableLike.scala:238)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at scala.collection.TraversableLike.map(TraversableLike.scala:238)
# 	at scala.collection.TraversableLike.map$(TraversableLike.scala:231)
# 	at scala.collection.immutable.List.map(List.scala:298)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.executeSql(SQLDriverLocal.scala:36)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.repl(SQLDriverLocal.scala:143)
# 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$10(DriverLocal.scala:431)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:237)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:232)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:229)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:48)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:274)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:267)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:48)
# 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:408)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:653)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:645)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.getCommandOutputAndError(DriverWrapper.scala:486)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:598)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:391)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:337)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:219)
# 	at java.lang.Thread.run(Thread.java:748)
#
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.executeSql(SQLDriverLocal.scala:128)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.repl(SQLDriverLocal.scala:143)
# 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$10(DriverLocal.scala:431)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:237)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:232)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:229)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:48)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:274)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:267)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:48)
# 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:408)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:653)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:645)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.getCommandOutputAndError(DriverWrapper.scala:486)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:598)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:391)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:337)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:219)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
# %sql
SHOW TABLES FROM DEFAULT;
DESCRIBE DETAIL DEFAULT.better_ip_results;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>parquet</td><td>null</td><td>default.better_ip_results</td><td></td><td>dbfs:/user/hive/warehouse/better_ip_results</td><td>2020-09-22T14:28:55.000+0000</td><td>null</td><td>List()</td><td>null</td><td>null</td><td>Map()</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
ACCESS_KEY = dbutils.secrets.get(scope = "aws-s3-prd", key = "ACCESS_KEY_ID")
SECRET_KEY = dbutils.secrets.get(scope = "aws-s3-prd", key = "SECRET_ACCESS_KEY")
ENCODED_SECRET_KEY = SECRET_KEY.replace("/", "%2F")
AWS_BUCKET_NAME = "td-infra-prd-us-east-1-s3-guardian"
MOUNT_NAME = "kafka_raw"


#display(dbutils.fs.ls("/mnt/%s" % MOUNT_NAME))

schema = spark.read.json("dbfs:/mnt/kafka_raw/57c7413abca837e974000009/audit_logs_1590969600000-1598918400000.json").schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs head "dbfs:/mnt/kafka_raw/57c7413abca837e974000009/audit_logs_1590969600000-1598918400000.json"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# {&quot;event_type&quot;:&quot;create_audit_operation&quot;,&quot;event_id&quot;:&quot;9dae685b6c964b28a05d4239a0cc00a6&quot;,&quot;logger_event_id&quot;:&quot;f2450cc2-73a5-44b6-aa52-9078def86425&quot;,&quot;account_id&quot;:&quot;57c7413abca837e974000009&quot;,&quot;agent_id&quot;:null,&quot;timestamp&quot;:&quot;2020-08-17T20:34:00.000&quot;,&quot;event&quot;:{&quot;logger_event_id&quot;:&quot;f2450cc2-73a5-44b6-aa52-9078def86425&quot;,&quot;logger_timestamp&quot;:&quot;2020-08-17T20:34:01.839000Z&quot;,&quot;timestamp&quot;:&quot;2020-08-17T20:34:00Z&quot;,&quot;account_id&quot;:&quot;57c7413abca837e974000009&quot;,&quot;audit&quot;:{&quot;resource_id&quot;:&quot;contacts/read/5f36ec714d05e3000ecb3319&quot;,&quot;operation&quot;:&quot;contact_read&quot;,&quot;severity&quot;:&quot;low&quot;,&quot;status&quot;:&quot;success&quot;,&quot;type&quot;:&quot;user&quot;},&quot;generator&quot;:{&quot;id&quot;:&quot;contacts-api-5b96dd888f-xvn4z&quot;,&quot;name&quot;:&quot;td-p-new-contacts-api&quot;,&quot;type&quot;:&quot;system&quot;},&quot;actor&quot;:{&quot;id&quot;:&quot;N/A&quot;,&quot;type&quot;:&quot;user&quot;,&quot;ip_addresses&quot;:[&quot;54.88.53.127&quot;],&quot;user_agent&quot;:&quot;Faraday v0.12.2&quot;},&quot;platform_tid&quot;:&quot;dd6ceeb1331db8e756b3a5999c907ce7, dd6ceeb1331db8e756b3a5999c907ce7&quot;,&quot;system&quot;:&quot;contacts_api&quot;,&quot;event&quot;:&quot;create_audit_operation&quot;,&quot;event_id&quot;:&quot;9dae685b6c964b28a05d4239a0cc00a6&quot;}}
# {&quot;event_type&quot;:&quot;create_audit_operation&quot;,&quot;event_id&quot;:&quot;bda6acb1777f48ac8294779ad0ce16eb&quot;,&quot;logger_event_id&quot;:&quot;901b96c0-2aca-45c5-bf42-51d550f49a32&quot;,&quot;account_id&quot;:&quot;57c7413abca837e974000009&quot;,&quot;agent_id&quot;:null,&quot;timestamp&quot;:&quot;2020-08-17T20:34:00.564&quot;,&quot;event&quot;:{&quot;logger_event_id&quot;:&quot;901b96c0-2aca-45c5-bf42-51d550f49a32&quot;,&quot;logger_timestamp&quot;:&quot;2020-08-17T20:34:01.839000Z&quot;,&quot;actor&quot;:{&quot;id&quot;:&quot;09278611f21847a88fdd48e3d664d2d4&quot;,&quot;type&quot;:&quot;oauth_client&quot;},&quot;generator&quot;:{&quot;id&quot;:&quot;talkdesk-id-web-5fd4c7878d-2ccdg&quot;,&quot;name&quot;:&quot;talkdesk-id&quot;,&quot;type&quot;:&quot;system&quot;},&quot;audit&quot;:{&quot;resource_id&quot;:&quot;84d0750ecab04935a81c447836b90662&quot;,&quot;operation&quot;:&quot;oauth_client_issue_access_token&quot;,&quot;status&quot;:&quot;success&quot;,&quot;severity&quot;:&quot;low&quot;,&quot;type&quot;:&quot;internal&quot;},&quot;account_id&quot;:&quot;57c7413abca837e974000009&quot;,&quot;realm&quot;:&quot;MAIN&quot;,&quot;object&quot;:{&quot;scopes&quot;:[&quot;apps:graphql&quot;,&quot;callbar&quot;,&quot;callbar-analytics:write&quot;,&quot;callbar-settings:read&quot;,&quot;device-routing-nailup:write&quot;,&quot;device-routing:read&quot;,&quot;device-routing:write&quot;,&quot;dispositions:read&quot;,&quot;graph-users:read&quot;,&quot;integrations-zendesk-tickets:read&quot;,&quot;interaction-quality-feedback:write&quot;,&quot;interaction-quality-settings:read&quot;,&quot;interaction-quality-settings:write&quot;,&quot;interactions:disconnect&quot;,&quot;interactions:hold&quot;,&quot;interactions:park&quot;,&quot;megazord:read&quot;,&quot;numbers:read&quot;,&quot;openid&quot;,&quot;permissions:verify&quot;,&quot;presence-user:read&quot;,&quot;ring-groups:read&quot;,&quot;rtm-settings:read&quot;,&quot;rtm-user:auth&quot;,&quot;sentiment-settings:read&quot;,&quot;ur:read&quot;,&quot;ur:write&quot;,&quot;user-session:end&quot;,&quot;users:read&quot;],&quot;grant_type&quot;:&quot;refresh_token&quot;,&quot;expiration_date&quot;:&quot;2020-08-17T20:44:00.564Z&quot;,&quot;principal_id&quot;:&quot;864ec8038c1241a39e1b211ca02823d0&quot;,&quot;subject_id&quot;:&quot;5d6431db70fc4d000c8b783a&quot;,&quot;refresh_token_id&quot;:&quot;ab7d99cfa31645d898bf65892a38aac7&quot;},&quot;event&quot;:&quot;create_audit_operation&quot;,&quot;timestamp&quot;:&quot;2020-08-17T20:34:00.564Z&quot;,&quot;event_id&quot;:&quot;bda6acb1777f48ac8294779ad0ce16eb&quot;}}
# {&quot;event_type&quot;:&quot;create_audit_operation&quot;,&quot;event_id&quot;:&quot;ad9c13eb0ca344f69b73d260899e8cd6&quot;,&quot;logger_event_id&quot;:&quot;15477153-e6df-434c-8e6f-e013dcfaa500&quot;,&quot;account_id&quot;:&quot;57c7413abca837e974000009&quot;,&quot;agent_id&quot;:null,&quot;timestamp&quot;:&quot;2020-08-17T20:34:00.605&quot;,&quot;event&quot;:{&quot;logger_event_id&quot;:&quot;15477153-e6df-434c-8e6f-e013dcfaa500&quot;,&quot;logger_timestamp&quot;:&quot;2020-08-17T20:34:01.840000Z&quot;,&quot;actor&quot;:{&quot;id&quot;:&quot;e69e94ce13ac4f78be90c1aa3ac90322&quot;,&quot;type&quot;:&quot;oauth_client&quot;},&quot;generator&quot;:{&quot;id&quot;:&quot;talkdesk-id-web-5fd4c7878d-pzs8k&quot;,&quot;name&quot;:&quot;talkdesk-id&quot;,&quot;type&quot;:&quot;system&quot;},&quot;audit&quot;:{&quot;resource_id&quot;:&quot;7010809c45034526baf78b962cab7dde&quot;,&quot;operation&quot;:&quot;oauth_client_issue_access_token&quot;,&quot;status&quot;:&quot;success&quot;,&quot;severity&quot;:&quot;low&quot;,&quot;type&quot;:&quot;internal&quot;},&quot;account_id&quot;:&quot;57c7413abca837e974000009&quot;,&quot;realm&quot;:&quot;MAIN&quot;,&quot;object&quot;:{&quot;scopes&quot;:[&quot;openid&quot;,&quot;users:read&quot;,&quot;user-roles:read&quot;,&quot;callbar&quot;,&quot;presence-user:read&quot;,&quot;presence-status:write&quot;,&quot;presence-occupancy:write&quot;,&quot;contacts:read&quot;,&quot;user-disposition-settings:read&quot;,&quot;contacts-integrations:read&quot;,&quot;account-custom-status:read&quot;,&quot;account:read&quot;,&quot;callbar-agents:write&quot;],&quot;grant_type&quot;:&quot;client_credentials&quot;,&quot;expiration_date&quot;:&quot;2020-08-17T20:44:00.604Z&quot;},&quot;event&quot;:&quot;create_audit_operation&quot;,&quot;timestamp&quot;:&quot;2020-08-17T20:34:00.605Z&quot;,&quot;event_id&quot;:&quot;ad9c13eb0ca344f69b73d260899e8cd6&quot;}}
# {&quot;event_type&quot;:&quot;create_audit_operation&quot;,&quot;event_id&quot;:&quot;cff8c3d2d3f14ee99b9f0e83d2a03877&quot;,&quot;logger_event_id&quot;:&quot;7bb21f6c-6f2f-44cf-b3fd-0f723263250b&quot;,&quot;account_id&quot;:&quot;57c7413abca837e974000009&quot;,&quot;agent_id&quot;:null,&quot;timestamp&quot;:&quot;2020-08-17T20:34:00.000&quot;,&quot;event&quot;:{&quot;logger_event_id&quot;:&quot;7bb21f6c-6f2f-44cf-b3fd-0f723263250b&quot;,&quot;logger_timestamp&quot;:&quot;2020-08-17T20:34:01.840000Z&quot;,&quot;timestamp&quot;:&quot;2020-08-17T20:34:00Z&quot;,&quot;account_id&quot;:&quot;57c7413abca837e974000009&quot;,&quot;audit&quot;:{&quot;resource_id&quot;:&quot;contacts/read/5f357a7e3b72b5000b99b642&quot;,&quot;operation&quot;:&quot;contact_read&quot;,&quot;severity&quot;:&quot;low&quot;,&quot;status&quot;:&quot;success&quot;,&quot;type&quot;:&quot;user&quot;},&quot;generator&quot;:{&quot;id&quot;:&quot;contacts-api-5b96dd888f-2z7hr&quot;,&quot;name&quot;:&quot;td-p-new-contacts-api&quot;,&quot;type&quot;:&quot;system&quot;},&quot;actor&quot;:{&quot;id&quot;:&quot;N/A&quot;,&quot;type&quot;:&quot;user&quot;,&quot;ip_addresses&quot;:[&quot;3.216.76.109&quot;],&quot;user_agent&quot;:&quot;Faraday v0.12.2&quot;},&quot;platform_tid&quot;:&quot;9a5ed7829ee59d9a51412fe5a2d57218, 9a5ed7829ee59d9a51412fe5a2d57218&quot;,&quot;system&quot;:&quot;contacts_api&quot;,&quot;event&quot;:&quot;create_audit_operation&quot;,&quot;event_id&quot;:&quot;cff8c3d2d3f14ee99b9f0e83d2a03877&quot;}}
# {&quot;event_type&quot;:&quot;create_audit_operation&quot;,&quot;event_id&quot;:&quot;325fba8968204a79add1055320ad8180&quot;,&quot;l

# %%
schema.json()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: &#39;{&#34;fields&#34;:[{&#34;metadata&#34;:{},&#34;name&#34;:&#34;account_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;agent_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;event&#34;,&#34;nullable&#34;:true,&#34;type&#34;:{&#34;fields&#34;:[{&#34;metadata&#34;:{},&#34;name&#34;:&#34;account_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;actor&#34;,&#34;nullable&#34;:true,&#34;type&#34;:{&#34;fields&#34;:[{&#34;metadata&#34;:{},&#34;name&#34;:&#34;id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;impersonated_user_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;ip_addresses&#34;,&#34;nullable&#34;:true,&#34;type&#34;:{&#34;containsNull&#34;:true,&#34;elementType&#34;:&#34;string&#34;,&#34;type&#34;:&#34;array&#34;}},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;session_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;type&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;user_agent&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;user_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;}],&#34;type&#34;:&#34;struct&#34;}},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;audit&#34;,&#34;nullable&#34;:true,&#34;type&#34;:{&#34;fields&#34;:[{&#34;metadata&#34;:{},&#34;name&#34;:&#34;operation&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;resource_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;severity&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;status&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;type&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;}],&#34;type&#34;:&#34;struct&#34;}},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;event&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;event_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;generator&#34;,&#34;nullable&#34;:true,&#34;type&#34;:{&#34;fields&#34;:[{&#34;metadata&#34;:{},&#34;name&#34;:&#34;client_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;name&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;type&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;}],&#34;type&#34;:&#34;struct&#34;}},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;logger_event_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;logger_timestamp&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;object&#34;,&#34;nullable&#34;:true,&#34;type&#34;:{&#34;fields&#34;:[{&#34;metadata&#34;:{},&#34;name&#34;:&#34;allowed_nailed_up_devices&#34;,&#34;nullable&#34;:true,&#34;type&#34;:{&#34;containsNull&#34;:true,&#34;elementType&#34;:&#34;string&#34;,&#34;type&#34;:&#34;array&#34;}},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;authorization_code_id&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;callID&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&#34;},{&#34;metadata&#34;:{},&#34;name&#34;:&#34;callSID&#34;,&#34;nullable&#34;:true,&#34;type&#34;:&#34;string&# ...

# %%
data = spark.readStream \
        .schema(schema) \
        .format("json").load("/mnt/kafka_raw/57c7413abca837e974000009/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import *

#reads current data as a stream
streamingInputDF = spark \
  .readStream \
  .schema(schema) \
  .format("json") \
  .option("maxFilesPerTrigger", 1) \
  .load("/mnt/kafka_raw/57c7413abca837e974000009/")

# Same query as staticInputDF
streamingCountsDF = (                 
  streamingInputDF
    .groupBy(
      streamingInputDF.account_id, 
      window(streamingInputDF.timestamp, "1 second"))
    .count()
)

# Is this DF actually a streaming DF?
streamingCountsDF.isStreaming

query = (
  streamingCountsDF
    .writeStream
    .format("memory")        # memory = store in-memory table 
    .queryName("counts")     # counts = name of the in-memory table
    .outputMode("complete")  # complete = all the counts should be in the table
    .start()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
