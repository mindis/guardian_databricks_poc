# %%
dbutils.widgets.removeAll()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd


dfs_train = spark.read.format('csv').option("inferSchema", 'false').option("header", 'true').option("sep", ',').load('/FileStore/tables/guide/qvt_train.csv')
dfs_test = spark.read.format('csv').option("inferSchema", 'false').option("header", 'true').option("sep", ',').load('/FileStore/tables/guide/qvt_test.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_train = dfs_train.toPandas()
df_train.sample(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>queries</th>
#       <th>is_question</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19731</th>
#       <td>What has been operated since 1562 at Transvaal...</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>128963</th>
#       <td>What do clinicians ignore the status of when t...</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>416630</th>
#       <td>materials system use</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>284825</th>
#       <td>nazi russian leaders meet discuss poland</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>32895</th>
#       <td>What is the spoken word of Chasidic Judiasm?</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4286</th>
#       <td>How many years does the story of To Kill a Moc...</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>345624</th>
#       <td>join atlanta hawks</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>227111</th>
#       <td>percentage aeta women hunt</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>200635</th>
#       <td>Did he have any wins during this time?</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>268333</th>
#       <td>society friends also known name</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_test = dfs_test.toPandas()
df_test.sample(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>queries</th>
#       <th>is_question</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2183</th>
#       <td>kustomer</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>970</th>
#       <td>calls report</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2941</th>
#       <td>call bar</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>586</th>
#       <td>remove agent</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2480</th>
#       <td>auto away</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2799</th>
#       <td>call back reporting</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1615</th>
#       <td>voice message</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1519</th>
#       <td>call barging</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1469</th>
#       <td>callbar salesforce</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2915</th>
#       <td>new agent</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_train = df_train.dropna()
df_train = df_train.drop(df_train.sample(frac=.5).index)

df_test = df_test.dropna()
df_test = df_test.drop(df_test.sample(frac=.5).index)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import mlflow
import mlflow.tensorflow

import tensorflow as tf
import tensorflow_hub as hub
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import nltk

def parse_query(qry):
    tokenizer = nltk.RegexpTokenizer(r"\w+")
    words = tokenizer.tokenize(qry)
    new_words = [word.lower() for word in words]
    return ' '.join(new_words)

def xyfromdf(df, embed):
    qrs = [parse_query(q) for q in df['queries']]
    X = embed(qrs)

    X = tf.make_ndarray(tf.make_tensor_proto(X))
    y = df['is_question'].values

    return X, y
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import mlflow.sklearn

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, f1_score

mlflow.set_experiment('/Users/pedro.rodrigues@talkdesk.com/pr_qvt')

with mlflow.start_run() as run:
  tfhub_enc = "https://tfhub.dev/google/universal-sentence-encoder/4"
  
  embed = hub.load(tfhub_enc)
  
  mlflow.log_param("encoder", tfhub_enc)
  
  X_train, y_train = xyfromdf(df_train, embed)
  X_test, y_test = xyfromdf(df_test, embed)
  
  clf_solver = 'lbfgs'

  mlflow.log_param("solver", clf_solver)
  clf = LogisticRegression(solver=clf_solver).fit(X_train, y_train)

  score_train = clf.score(X_train, y_train)
  print("Train score: %s" % score_train)

  score_test = clf.score(X_test, y_test)
  print("Test score: %s" % score_test)

  mlflow.log_metric("score_train", score_train)
  mlflow.log_metric("score_test", score_test)
  mlflow.sklearn.log_model(clf, "model")
  print("Model saved in run %s" % mlflow.active_run().info.run_uuid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Train score: 0.9936642720239183
# Test score: 0.978604177279674
# Model saved in run f8e74cfcf9c64a38b2c33162af789b90
# </div>

# %%
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

#mlflow.log_metric("confusion_matrix_test", cm)
print(cm)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[[1694    8]
#  [  34  227]]
# </div>

# %%
import numpy as np

def single_predict(q, clf):
    qrs = [parse_query(q)]
    X = embed(qrs)

    X = tf.make_ndarray(tf.make_tensor_proto(X))
    
    p = clf.predict(X)[0]
    
    return float(p) > .5
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
qry = 'am i a muppet'
print('the query is a question:', single_predict(qry, clf))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">the query is a question: True
# </div>
